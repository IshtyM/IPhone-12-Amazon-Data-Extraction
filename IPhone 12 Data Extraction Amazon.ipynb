# %% [markdown]
# ### Extracting the URL

# %%
from IPhone_12_Function_File import *
url=get_url('lenovo laptops')
print(url)
# Out:
# ...
# https://www.amazon.in/New-Apple-ilenovo-laptops-64GB/product-reviews/B08L5TGWD1?reviewerType=all_reviews

# %% [markdown]
# ### Extracting The Data

# %%
from IPhone_12_Function_File import *
main("Iphone 12")

# %%
len(list)
# Out:
# 436

# %%
import pandas as pd
Data=pd.DataFrame(list)
Data.columns=['Customer Name','Review Title','Date of Post','Product Name','Rating','Given Reviews','Image Link', 'Post is Helpful']

Data
# Out:
#           Customer Name                                       Review Title  \
# 0          Tarun barath                                     Worst battery
# 1       S.Siva Ram Kris   Another Fabulous IPhone ( IPhone 12, Blue 64GB)
# 2                 Paras                                         The Beast
# 3       Amazon Customer                         Kidney as a load balancer
# 4         Ayush taliyan                        NOW I ONLY HAVE ONE KIDNEY
# ..                  ...                                                ...
# 431               Arjun                                     It just works
# 432          Saurabh D.   Service Woes....Defective product combined wi...
# 433         harsh gupta                                              Good
# 434  Malay Kumar Sarkar   Not happy with Amazon Customer service s no r...
# 435      abhishek kumar                                                Ok
#
#                               Date of Post  \
# ...

# %%
from IPhone_12_Function_File import *

Data.style.format({'Image Link': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_99e76432_ae35_11eb_854a_d8d0904811a7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Customer Name</th>        <th class="col_heading level0 col1" >Review Title</th>        <th class="col_heading level0 col2" >Date of Post</th>        <th class="col_heading level0 col3" >Product Name</th>        <th class="col_heading level0 col4" >Rating</th>        <th class="col_heading level0 col5" >Given Reviews</th>        <th class="col_heading level0 col6" >Image Link</th>        <th class="col_heading level0 col7" >Post is Helpful</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99e76432_ae35_11eb_854a_d8d0904811a7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_99e76432_ae35_11eb_854a_d8d0904811a7row0_col0" class="data row0 col0" >Tarun barath</td>
# ...

# %%
Data.to_csv('d:Ishty Folder\Projects Python\Iphone 12 Amazon List.csv', mode='a',header=True)
